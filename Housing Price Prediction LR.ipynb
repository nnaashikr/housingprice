# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dt=pd.read_csv('C:/Users/sharu/Desktop/housing.csv',header=0)

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dt.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
sns.jointplot(x='total_rooms',y='median_house_value',data=dt)

# %%
sns.jointplot(x='total_bedrooms',y='median_house_value',data=dt)

# %%
sns.jointplot(x='population',y='median_house_value',data=dt)

# %%
sns.jointplot(x='households',y='median_house_value',data=dt)

# %%
sns.jointplot(x='median_income',y='median_house_value',data=dt)

# %%
uv=np.percentile(dt.total_rooms,[98])[0]

# %%
dt.total_rooms[dt.total_rooms>uv]=uv
# Out:
# <ipython-input-11-9b04be08ef49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt.total_rooms[dt.total_rooms>uv]=uv

# %%
ut=np.percentile(dt.total_bedrooms,[98])[0]

# %%
dt.total_bedrooms[dt.total_bedrooms>ut]=ut
# Out:
# <ipython-input-13-5cb6629e47e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt.total_bedrooms[dt.total_bedrooms>ut]=ut

# %%
uh=np.percentile(dt.population,[98])[0]

# %%
dt.population[dt.population>uh]=uh
# Out:
# <ipython-input-15-ce39f105c092>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt.population[dt.population>uh]=uh

# %%
ul=np.percentile(dt.households,[98])[0]

# %%
dt.households[dt.households>ul]=ul
# Out:
# <ipython-input-17-50725a310ae2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt.households[dt.households>ul]=ul

# %%
uk=np.percentile(dt.median_income,[98])[0]

# %%
dt.median_income[dt.median_income>uk]=uk
# Out:
# <ipython-input-19-77dd37d5f3ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt.median_income[dt.median_income>uk]=uk

# %%
sns.jointplot(x='total_rooms',y='median_house_value',data=dt)

# %%
sns.jointplot(x='total_bedrooms',y='median_house_value',data=dt)

# %%
sns.jointplot(x='population',y='median_house_value',data=dt)

# %%
sns.jointplot(x='households',y='median_house_value',data=dt)

# %%
sns.jointplot(x='median_income',y='median_house_value',data=dt)

# %%
dt=dt.fillna(dt.mean())

# %%
dt=pd.get_dummies(dt)

# %%
dt.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2553.639814
# std        2.003532      2.135952           12.585558   1719.513128
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000   8853.520000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1386.547460    486.495979       3.824845
# std        419.266592    905.816278    314.698362       1.722915
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
del dt['ocean_proximity_<1H OCEAN']

# %%
dt.corr()
# Out:
#                             longitude  latitude  housing_median_age  \
# longitude                    1.000000 -0.924664           -0.108197
# latitude                    -0.924664  1.000000            0.011173
# housing_median_age          -0.108197  0.011173            1.000000
# total_rooms                  0.038505 -0.032158           -0.386091
# total_bedrooms               0.069260 -0.066658           -0.318998
# population                   0.112154 -0.124922           -0.313842
# households                   0.056368 -0.076204           -0.314336
# median_income               -0.015327 -0.083700           -0.137369
# median_house_value          -0.045967 -0.144160            0.105623
# ocean_proximity_INLAND      -0.055575  0.351166           -0.236645
# ocean_proximity_ISLAND       0.009446 -0.016572            0.017020
# ocean_proximity_NEAR BAY    -0.474489  0.358771            0.255172
# ocean_proximity_NEAR OCEAN   0.045509 -0.160818            0.021622
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
X=dt.drop("median_house_value",axis=1)

# %%
y=dt['median_house_value']

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  ocean_proximity_INLAND  \
# 0       322.0       126.0         8.3252                       0
# 1      2401.0      1138.0         8.3014                       0
# 2       496.0       177.0         7.2574                       0
# 3       558.0       219.0         5.6431                       0
# 4       565.0       259.0         3.8462                       0
#
#    ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                       0                         1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a=lm.predict(X_test)

# %%
y_train_a=lm.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.6481186716782098

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.6633376959046675
